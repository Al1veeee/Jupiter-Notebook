# %% [markdown]
# <a href="https://colab.research.google.com/github/Al1veeee/Jupiter-Notebook/blob/main/%D0%92%D0%BE%D0%BF%D1%80%D0%BE%D1%81%D1%8B_%D0%BF%D0%BE_2_%D0%BB%D0%B5%D0%BA%D1%86%D0%B8%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Из каких этапов состоит процесс подготовки данных к анализу?**
# Основные этапы этого процесса включают сбор, фильтрацию и разметку необработанных данных в форме, подходящей для алгоритмов машинного обучения (ML), а также последующее изучение и визуализацию данных.
#
# # **2. Сформулируйте определение понятия данных в машинном обучении?**
# Данные в машинном обучении – это представление информации об
# исследуемой задаче в виде множеств исследуемых объектов и множеств их
# характеристик, на основе которых строятся модели, разрабатываются
# подходы, методы и алгоритмы анализа для принятия решений.
#
# # **3. Назовите ключевые требования к данным.**
# Качество данных – важный аспект машинного обучения.
# Основные требования к данным:
# 1.   Доступность.
# 2.   Точность.
# 3.   Полнота.
# 4.   Непротиворечивость.
# 5.   Однозначность.
# 6.   Релевантность.
# 7.   Надежность.
# 8.   Своевременность.
# 9.   Взаимосвязанность.
#
# # **4. Приведите основные этапы решения задачи машинного обучения.**
# Этапы решения задач машинного обучения:
# 1.   Постановка задачи.
# 2.   Сбор и подготовка данных.
# 3.   Предобработка данных и выделение ключевых признаков.
# 4.   Выбор алгоритмов машинного обучения
# 5.   Обучение модели (моделей)
# 6.   Оценка качества.
# 7.   Эксплуатация модели при достижении требуемого качества, либо
# возврат к одному из предыдущих шагов (перенастройка модели, добыча
# новых данных и т. п.).
#
# # **5. Почему необходимо производить обработку данных?**
# Он позволяет извлечь новые признаки и улучшить модель, выявить скрытые зависимости и сделать более точные прогнозы, способен улучшить интерпретируемость модели и сократить время обучения.
#
# # **6. Какие операции можно применять при подготовке данных?**
# # **7. Охаректеризуйте ключевые операции, которые применяют при подготовке данных.**
# При подготовке данных можно применять следующие операции:
# 1. структурирование – приведение данных к табличному
# (матричному) виду;
# 2. заполнение пропусков;
# 3. отбор – исключение записей с отсутствующими или
# некорректными значениями, если нет возможности заполнения и устранения
# противоречивости;
# 4. нормализация – приведение числовых значений к определенному
# диапазону, например к диапазону 0...1;
# 5. кодирование – это представление категориальных данных в
# числовой форме. Например, при бинарной классификации один из классов
# можно представить числом «0», а другой класс – числом «1».
#
# # **8. Что показывают категориальные признаки?**
# # **9. Можно ли перевести категориальные признаки к числовым значениям?**
# Это признак, значения которого обозначают принадлежность объекта к какой-то категории.
#
# Пол: Ж-0, М-1
#
# Например, при бинарной классификации один из классов
# можно представить числом «0», а другой класс – числом «1».
#
# # **10. Приведите известные Вам методы нормировки данных. Для чего они нужны?**
# Нормировка данных - это процесс приведения значений переменных к определенному диапазону или распределению. Она выполняется с целью обеспечения стабильности и сопоставимости данных в различных масштабах. Вот несколько известных методов нормировки данных:![123fdfdfdf.jpg](data:image/jpeg;base64,...)
